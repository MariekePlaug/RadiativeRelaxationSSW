# %%
# imports

import sys
import os

import matplotlib.pyplot as plt
import netCDF4 as netcdf4
import numpy as np
import pyarts3 as pyarts
import typhon as ty
import xarray as xr

import src.SSW_functions as ssw

os.chdir('..')

# %%
solar_2004, thermal_2004, altitude_2004, net_thermal_2004, net_solar_2004, net_total_2004 = ssw.calculate_fluxes(2004, species_list=["CO2", "NO2", "NO", "O3", "H2O", "O2", "N2"], force_recalculate=True)
# Out:
# Calculating fluxes for year 2004
# Fluxes saved to flux_data/fluxes_2004.npz

# %%
solar_2006, thermal_2006, altitude_2006, net_thermal_2006, net_solar_2006, net_total_2006 = ssw.calculate_fluxes(2006, species_list=["CO2", "NO2", "NO", "O3", "H2O", "O2", "N2"], force_recalculate=True)
# Out:
# Calculating fluxes for year 2006
# Fluxes saved to flux_data/fluxes_2006.npz

# %%
solar_2007, thermal_2007, altitude_2007, net_thermal_2007, net_solar_2007, net_total_2007 = ssw.calculate_fluxes(2007, species_list=["CO2", "NO2", "NO", "O3", "H2O", "O2", "N2"], force_recalculate=True)
# Out:
# Calculating fluxes for year 2007
# Fluxes saved to flux_data/fluxes_2007.npz

# %%
solar_2008, thermal_2008, altitude_2008, net_thermal_2008, net_solar_2008, net_total_2008 = ssw.calculate_fluxes(2008, species_list=["CO2", "NO2", "NO", "O3", "H2O", "O2", "N2"], force_recalculate=True)
# Out:
# Calculating fluxes for year 2008
# Fluxes saved to flux_data/fluxes_2008.npz

# %%
solar_2009, thermal_2009, altitude_2009, net_thermal_2009, net_solar_2009, net_total_2009 = ssw.calculate_fluxes(2009, species_list=["CO2", "NO2", "NO", "O3", "H2O", "O2", "N2"], force_recalculate=True)
# Out:
# Calculating fluxes for year 2009
# Fluxes saved to flux_data/fluxes_2009.npz

# %%
solar_2010, thermal_2010, altitude_2010, net_thermal_2010, net_solar_2010, net_total_2010 = ssw.calculate_fluxes(2010, species_list=["CO2", "NO2", "NO", "O3", "H2O", "O2", "N2"], force_recalculate=True)
# Out:
# Calculating fluxes for year 2010
# Fluxes saved to flux_data/fluxes_2010.npz

# %%
solar_20013, thermal_2013, altitude_2013, net_thermal_2013, net_solar_2013, net_total_2013 = ssw.calculate_fluxes(2013, species_list=["CO2", "NO2", "NO", "O3", "H2O", "O2", "N2"], force_recalculate=True)
# Out:
# Calculating fluxes for year 2013
# Fluxes saved to flux_data/fluxes_2013.npz
